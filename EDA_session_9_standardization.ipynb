# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
visa_df=pd.read_csv("Visadataset.csv")

# %% [markdown]
# **Standardization**
#
# - standardization is a technique to scale all the data in one scale
#
# - Different columns has different values also different units
#
# - Some column values has bigger values,some column values has lesser values
#
# - So it is important to keep all the values under one scale
#
# - We have two methods are there
#
#    - Standardization
#
#    - Normalization
#
# - Standardization
#
#   - Z-score
#
#   - Z score varies from -3 to 3
#
#   - z=x-u/sigma

# %% [markdown]
# **Normalization**
#
# - min max scalar
#
# - values are ranges from 0 to 1
#
# - x(scaled)=x-xmin/xmax-xmin

# %%
#Task
#step-1:take previling wage column 

#step-2:Calculate the mean value of that column

#step-3:calculate the standart deviation of the previlling wage

#step-4:calculate the Nr:step1-step2

#step-5:divide the step4/step3

# %%
a=visa_df['prevailing_wage']
mean=visa_df['prevailing_wage'].mean()
std=visa_df['prevailing_wage'].std()
b=(a-mean)/std
visa_df['prevailing_wage_z']=b
visa_df
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 0         EZYV01      Asia           High School                  N
# 1         EZYV02      Asia              Master's                  Y
# 2         EZYV03      Asia            Bachelor's                  N
# 3         EZYV04      Asia            Bachelor's                  N
# 4         EZYV05    Africa              Master's                  Y
# ...          ...       ...                   ...                ...
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# ...

# %% [markdown]
# **idmax-idmin**

# %%
maxx=visa_df["prevailing_wage"].idxmax(),visa_df["prevailing_wage_z"].idxmax()
minn=visa_df["prevailing_wage"].idxmin(),visa_df["prevailing_wage_z"].idxmin()

# %%
maxx,minn
# Out:
# ((21077, 21077), (20575, 20575))

# %% [markdown]
# **StandardScalar**
#
# - StandardScalar same as z-score but by using package
#
# - it is under sklearn we have preprocessign
#
# - read the package
#
# - save the package
#
# - apply the fit transform
#
# - compare 3 columns
#
# - one is original
#
# - manually we did z-score
#
# - column with package

# %%
from sklearn.preprocessing import Standardscaler
ss=Standardscaler()
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[32], line 1
# ----> 1 from sklearn.preprocessing import Standardscaler
#       2 ss=Standardscaler()
#
# ImportError: cannot import name 'Standardscaler' from 'sklearn.preprocessing' (C:\Users\Vinay\anaconda3\Lib\site-packages\sklearn\preprocessing\__init__.py)

# %% [markdown]
# **Normalization**
